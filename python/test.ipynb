# %%
# Out:
#   Cell In[9], line 1
#     from __future__ import braces
#                            ^
# SyntaxError: not a chance

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 this.tab
#
# AttributeError: module 'this' has no attribute 'tab'
