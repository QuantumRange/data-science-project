# %%
import pandas as pd

# %%
df = pd.read_parquet("/Users/qr/Downloads/c00421.parquet", engine='fastparquet')

# %%
df[df.status == 200].sort_values(by=['duration'], ascending=False).head(5)

# %%
df.group
