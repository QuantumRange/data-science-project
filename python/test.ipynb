# %%
import pandas as pd

# %%
df = pd.read_parquet("/Users/qr/Downloads/c00421.parquet", engine='fastparquet')

# %%
df.drop(columns=['id', 'domain', 'url', 'timestamp', 'text', 'header', 'links', 'type']).groupby('http_version').agg('mean')
# Out:
#                 duration      status
# http_version
# 2             364.599141  219.898222
# 3             128.500000  401.000000
