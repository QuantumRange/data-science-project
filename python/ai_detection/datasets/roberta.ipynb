# %%
from transformers import pipeline
import polars as pl

# %%
(pl
 .scan_parquet("/mnt/Fast2T/data/link/c00001.parquet")
 .select("id", "url", "")
 )
# Out:
# shape: (83_511, 13)
# ┌─────────┬────────┬─────────────┬────────────┬───┬─────────┬────────────┬────────────┬────────────┐
# │ id      ┆ domain ┆ url         ┆ timestamp  ┆ … ┆ lang    ┆ lang_confi ┆ text       ┆ outflow    │
# │ ---     ┆ ---    ┆ ---         ┆ ---        ┆   ┆ ---     ┆ dence      ┆ ---        ┆ ---        │
# │ i64     ┆ i64    ┆ str         ┆ i64        ┆   ┆ str     ┆ ---        ┆ str        ┆ str        │
# │         ┆        ┆             ┆            ┆   ┆         ┆ f32        ┆            ┆            │
# ╞═════════╪════════╪═════════════╪════════════╪═══╪═════════╪════════════╪════════════╪════════════╡
# │ 8336339 ┆ 50298  ┆ https://www ┆ 1770526459 ┆ … ┆ ENGLISH ┆ 0.897004   ┆ adviser    ┆ {}         │
# │         ┆        ┆ .australian ┆ 855        ┆   ┆         ┆            ┆ australia  ┆            │
# │         ┆        ┆ ethical.…   ┆            ┆   ┆         ┆            ┆ ethical    ┆            │
# │         ┆        ┆             ┆            ┆   ┆         ┆            ┆ skip…      ┆            │
# │ 8336341 ┆ 140424 ┆ https://www ┆ 1766230987 ┆ … ┆ CHINESE ┆ 0.981422   ┆ 光明 网    ┆ {}         │
# │         ┆        ┆ .gmw.cn     ┆ 399        ┆   ┆         ┆            ┆ 新闻 视野  ┆            │
# │         ┆        ┆             ┆            ┆   ┆         ┆            ┆ 文化 视角  ┆            │
# │         ┆        ┆             ┆            ┆   ┆         ┆            ┆ 思想 深度  ┆            │
# │         ┆        ┆             ┆            ┆   ┆         ┆            ┆ 理论 高度  ┆            │
# │         ┆        ┆             ┆            ┆   ┆         ┆            ┆ 知…        ┆            │
# │ 8336342 ┆ 50313  ┆ https://hhg ┆ 1770635654 ┆ … ┆ GREEK   ┆ 0.997592   ┆ creta inte ┆ {}         │
# │         ┆        ┆ .gr/el/%CE% ┆ 636        ┆   ┆         ┆            ┆ rclinic x  ┆            │
# │         ┆        ┆ B8%CE%B5…   ┆            ┆   ┆         ┆            ┆ αναζητησ   ┆            │
# │         ┆        ┆             ┆            ┆   ┆         ┆            ┆ ε…         ┆            │
# │ 8336343 ┆ 123388 ┆ https://tal ┆ 1770586939 ┆ … ┆ ENGLISH ┆ 0.822263   ┆ tpm talk   ┆ {}         │
# │         ┆        ┆ kingpointsm ┆ 110        ┆   ┆         ┆            ┆ points     ┆            │
# │         ┆        ┆ emo.com/    ┆            ┆   ┆         ┆            ┆ memo break ┆            │
# │         ┆        ┆             ┆            ┆   ┆         ┆            ┆ new…       ┆            │
# │ 8336344 ┆ 50311  ┆ https://www ┆ 1766081553 ┆ … ┆ UNKNOWN ┆ 0.0        ┆            ┆ {}         │
# │         ┆        ┆ .maroochysu ┆ 800        ┆   ┆         ┆            ┆            ┆            │
# │         ┆        ┆ rfclub.c…   ┆            ┆   ┆         ┆            ┆            ┆            │
# │ …       ┆ …      ┆ …           ┆ …          ┆ … ┆ …       ┆ …          ┆ …          ┆ …          │
# │ 8630758 ┆ 153605 ┆ http://star ┆ 1770107512 ┆ … ┆ UNKNOWN ┆ 0.0        ┆            ┆ {}         │
# │         ┆        ┆ ai.cs.ucla. ┆ 262        ┆   ┆         ┆            ┆            ┆            │
# │         ┆        ┆ edu/pape…   ┆            ┆   ┆         ┆            ┆            ┆            │
# │ 8630759 ┆ 199085 ┆ https://adi ┆ 1766301496 ┆ … ┆ ENGLISH ┆ 0.821577   ┆ adium      ┆ {}         │
# │         ┆        ┆ um.im/      ┆ 513        ┆   ┆         ┆            ┆ download   ┆            │
# │         ┆        ┆             ┆            ┆   ┆         ┆            ┆ adium      ┆            │
# │         ┆        ┆             ┆            ┆   ┆         ┆            ┆ download … ┆            │
# │ 8630767 ┆ 234389 ┆ http://kwch ┆ 1767131826 ┆ … ┆ UNKNOWN ┆ 0.0        ┆            ┆ {"15":1,"1 │
# │         ┆        ┆ ang.net/doc ┆ 942        ┆   ┆         ┆            ┆            ┆ 0302":1,"3 │
# │         ┆        ┆ uments/s…   ┆            ┆   ┆         ┆            ┆            ┆ 211585":1} │
# │ 8630772 ┆ 52207  ┆ https://png ┆ 1766104476 ┆ … ┆ ENGLISH ┆ 0.933187   ┆ pngquant2  ┆ {}         │
# │         ┆        ┆ quant.org/v ┆ 176        ┆   ┆         ┆            ┆ vs         ┆            │
# │         ┆        ┆ sphotosh…   ┆            ┆   ┆         ┆            ┆ photoshop  ┆            │
# │         ┆        ┆             ┆            ┆   ┆         ┆            ┆ save we…   ┆            │
# │ 8630774 ┆ 234389 ┆ http://kwch ┆ 1766447923 ┆ … ┆ UNKNOWN ┆ 0.0        ┆            ┆ {"4":1}    │
# │         ┆        ┆ ang.net/doc ┆ 081        ┆   ┆         ┆            ┆            ┆            │
# │         ┆        ┆ uments/s…   ┆            ┆   ┆         ┆            ┆            ┆            │
# └─────────┴────────┴─────────────┴────────────┴───┴─────────┴────────────┴────────────┴────────────┘

# %%
pipe = pipeline("text-classification", model="roberta-base-openai-detector")
# Out:
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: roberta-base-openai-detector
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# roberta.pooler.dense.weight | UNEXPECTED |  |
# roberta.pooler.dense.bias   | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
print(pipe("Hello world! Is this content AI-generated?"))
# Out:
# [{'label': 'Real', 'score': 0.8036585450172424}]
